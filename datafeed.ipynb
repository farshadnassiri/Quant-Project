# %%
import requests
import matplotlib.pyplot as plt

def fetch_deribit_options(currency="BTC"):
    url = "https://www.deribit.com/api/v2/public/get_instruments"
    params = {
        "currency": currency,
        "kind": "option",
        "expired": "false"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()["result"]
        return data
    else:
        print("Error fetching data:", response.status_code, response.text)
        return None

# Fetch BTC Options
data = []
option_chain = fetch_deribit_options()
for option in option_chain[:]:
  name = option['instrument_name'].split("-")[1]
  if name == "8NOV25":
    data.append(option)

data
# Out:
# [{'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-92000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762291920000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 92000.0,
#   'instrument_id': 545310,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-92000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762291920000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 92000.0,
#   'instrument_id': 545311,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-94000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762275900000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 94000.0,
#   'instrument_id': 545046,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-94000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762275900000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 94000.0,
#   'instrument_id': 545047,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-96000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243320000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 96000.0,
#   'instrument_id': 544848,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-96000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243320000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 96000.0,
#   'instrument_id': 544849,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-97000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762279440000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 97000.0,
#   'instrument_id': 545082,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-97000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762279440000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 97000.0,
#   'instrument_id': 545083,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-98000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 98000.0,
#   'instrument_id': 544668,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-98000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 98000.0,
#   'instrument_id': 544669,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-99000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762267080000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 99000.0,
#   'instrument_id': 545000,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-99000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762267080000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 99000.0,
#   'instrument_id': 545001,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-100000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 100000.0,
#   'instrument_id': 544670,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-100000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 100000.0,
#   'instrument_id': 544671,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-101000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 101000.0,
#   'instrument_id': 544672,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-101000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 101000.0,
#   'instrument_id': 544673,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-102000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 102000.0,
#   'instrument_id': 544674,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-102000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 102000.0,
#   'instrument_id': 544675,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-103000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 103000.0,
#   'instrument_id': 544676,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-103000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 103000.0,
#   'instrument_id': 544677,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-104000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 104000.0,
#   'instrument_id': 544678,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-104000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 104000.0,
#   'instrument_id': 544679,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-105000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 105000.0,
#   'instrument_id': 544680,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-105000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 105000.0,
#   'instrument_id': 544681,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-106000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 106000.0,
#   'instrument_id': 544682,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-106000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 106000.0,
#   'instrument_id': 544683,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-107000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 107000.0,
#   'instrument_id': 544684,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-107000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 107000.0,
#   'instrument_id': 544685,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-108000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 108000.0,
#   'instrument_id': 544686,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-108000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 108000.0,
#   'instrument_id': 544687,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-110000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 110000.0,
#   'instrument_id': 544688,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-110000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 110000.0,
#   'instrument_id': 544689,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-112000-C',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'call',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 112000.0,
#   'instrument_id': 544690,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]},
#  {'price_index': 'btc_usd',
#   'kind': 'option',
#   'instrument_name': 'BTC-8NOV25-112000-P',
#   'maker_commission': 0.0003,
#   'taker_commission': 0.0003,
#   'instrument_type': 'reversed',
#   'expiration_timestamp': 1762588800000,
#   'creation_timestamp': 1762243211000,
#   'is_active': True,
#   'option_type': 'put',
#   'contract_size': 1.0,
#   'tick_size': 0.0001,
#   'strike': 112000.0,
#   'instrument_id': 544691,
#   'min_trade_amount': 0.1,
#   'block_trade_commission': 0.0003,
#   'block_trade_min_trade_amount': 25,
#   'block_trade_tick_size': 0.0001,
#   'settlement_currency': 'BTC',
#   'settlement_period': 'day',
#   'base_currency': 'BTC',
#   'counter_currency': 'USD',
#   'quote_currency': 'BTC',
#   'tick_size_steps': [{'tick_size': 0.0005, 'above_price': 0.005}]}]
